# %%
# %matplotlib inline
# %reset -f
import pandas as pd
import numpy as np
from scipy.stats import beta
import matplotlib.pyplot as plt
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import statsmodels.api as sm
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('cannabis.csv')
data = df.dropna(how = 'any')

# %%
tipo = np.array(data.Type)
label_encoder = LabelEncoder()
Type_quan = label_encoder.fit_transform(tipo)
Type_quan
data = data.assign(Tipo = Type_quan)

# %%
efeitos = data['Effects'].str.get_dummies(sep=',')
efeitos = efeitos.drop("None", axis =1)

# %%
data_nova = data.join(efeitos, how = 'inner')

# %%
sabores = data['Flavor'].str.get_dummies(sep=',')
sabores = sabores.drop("None", axis =1)

# %%
datanova = data_nova.join(sabores, how = 'inner')

# %%
datanova1 = datanova.drop(['Effects','Flavor','Type','Strain','Description'], 1)

# %%
datanova1.columns
# Out:
# Index(['Rating', 'Tipo', 'Aroused', 'Creative', 'Dry', 'Energetic', 'Euphoric',
#        'Focused', 'Giggly', 'Happy', 'Hungry', 'Mouth', 'Relaxed', 'Sleepy',
#        'Talkative', 'Tingly', 'Uplifted', 'Ammonia', 'Apple', 'Apricot',
#        'Berry', 'Blue', 'Blueberry', 'Butter', 'Cheese', 'Chemical',
#        'Chestnut', 'Citrus', 'Coffee', 'Diesel', 'Earthy', 'Flowery', 'Fruit',
#        'Grape', 'Grapefruit', 'Honey', 'Lavender', 'Lemon', 'Lime', 'Mango',
#        'Menthol', 'Mint', 'Minty', 'Nutty', 'Orange', 'Peach', 'Pear',
#        'Pepper', 'Pine', 'Pineapple', 'Plum', 'Pungent', 'Rose', 'Sage',
#        'Skunk', 'Spicy/Herbal', 'Strawberry', 'Sweet', 'Tar', 'Tea', 'Tobacco',
#        'Tree', 'Tropical', 'Vanilla', 'Violet', 'Woody'],
#       dtype='object')

# %%
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
Y = datanova1['Rating']
X = datanova1[[ 'Aroused', 'Creative', 'Dry', 'Energetic', 'Euphoric',
       'Focused', 'Giggly', 'Happy', 'Hungry', 'Mouth', 'Relaxed', 'Sleepy',
       'Talkative', 'Tingly', 'Uplifted']]

# %%
results = regress(X,Y)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.428
# Model:                            OLS   Adj. R-squared:                  0.425
# Method:                 Least Squares   F-statistic:                     121.0
# Date:                Thu, 08 Nov 2018   Prob (F-statistic):          5.90e-262
# Time:                        09:56:31   Log-Likelihood:                -2145.2
# No. Observations:                2277   AIC:                             4320.
# Df Residuals:                    2262   BIC:                             4406.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7278      0.065     26.705      0.000       1.601       1.855
# Aroused        0.5517      0.048     11.465      0.000       0.457       0.646
# Creative       0.5517      0.031     17.939      0.000       0.491       0.612
# Dry            1.1361      0.313      3.629      0.000       0.522       1.750
# Energetic      0.5412      0.034     15.845      0.000       0.474       0.608
# Euphoric       0.5400      0.031     17.683      0.000       0.480       0.600
# Focused        0.5161      0.032     16.031      0.000       0.453       0.579
# Giggly         0.4525      0.042     10.764      0.000       0.370       0.535
# Happy          0.5248      0.035     15.106      0.000       0.457       0.593
# Hungry         0.4509      0.036     12.514      0.000       0.380       0.522
# Mouth          1.1361      0.313      3.629      0.000       0.522       1.750
# Relaxed        0.6743      0.035     19.396      0.000       0.606       0.742
# Sleepy         0.4967      0.033     14.862      0.000       0.431       0.562
# Talkative      0.5547      0.038     14.446      0.000       0.479       0.630
# Tingly         0.4803      0.039     12.395      0.000       0.404       0.556
# Uplifted       0.5156      0.030     17.043      0.000       0.456       0.575
# ==============================================================================
# Omnibus:                      621.229   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20884.032
# Skew:                          -0.611   Prob(JB):                         0.00
# Kurtosis:                      17.786   Cond. No.                     2.58e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#datanova1["is_duplicated"]= datanova1.duplicated(keep=False)
#dataset = datanova1[datanova1.is_duplicated==True]

# %%
# Out:
#       Tipo  Aroused  Creative  Dry  Energetic  Euphoric  Focused  Giggly  \
# 5        1        0         0    0          0         0        0       0
# 6        0        0         0    0          0         1        0       0
# 9        1        0         0    0          0         1        0       0
# 16       1        0         0    0          0         0        0       0
# 17       1        0         0    0          0         1        0       0
# 23       0        0         0    0          1         1        0       0
# 29       1        0         0    0          0         1        0       0
# 33       0        0         0    0          0         1        0       0
# 42       0        0         1    0          1         1        1       0
# 43       1        0         0    0          0         1        0       0
# 49       1        0         0    0          0         1        0       0
# 54       2        0         0    0          0         0        0       0
# 56       0        0         0    0          0         1        0       0
# 72       1        0         0    0          0         1        0       0
# 73       1        0         0    0          0         1        0       0
# 78       0        0         1    0          0         1        0       0
# 94       2        0         0    0          0         0        0       0
# 106      2        0         0    0          0         0        0       0
# 110      1        0         0    0          0         1        0       0
# 112      0        0         1    0          0         1        0       0
# 126      0        0         1    0          0         1        0       0
# 137      0        0         0    0          0         1        0       0
# 142      1        0         0    0          0         1        0       0
# 150      0        0         0    0          0         1        0       0
# 151      0        0         0    0          0         1        0       0
# 177      2        0         0    0          0         1        1       0
# 187      0        0         0    0          0         0        0       0
# 190      1        0         0    0          0         1        0       0
# 191      0        0         0    0          0         1        0       0
# 192      1        0         0    0          0         1        0       0
# ...    ...      ...       ...  ...        ...       ...      ...     ...
# 2174     1        0         0    0          0         0        0       0
# 2179     0        0         1    0          0         1        0       0
# 2180     1        0         0    0          0         1        0       0
# 2201     1        0         0    0          0         1        0       0
# 2202     0        0         0    0          0         0        0       0
# 2220     1        0         0    0          0         1        0       0
# 2229     0        0         0    0          0         1        0       0
# 2231     0        0         1    0          0         1        0       0
# 2249     0        0         0    0          1         1        0       0
# 2256     0        0         1    0          0         1        0       0
# 2262     0        0         0    0          1         1        0       0
# 2264     1        0         0    0          0         1        0       0
# 2269     0        0         0    0          0         0        0       0
# 2270     0        0         0    0          0         1        1       0
# 2273     1        0         0    0          0         1        0       0
# 2274     0        0         0    0          1         1        0       0
# 2276     0        0         0    0          0         1        0       0
# 2278     1        0         0    0          0         1        0       0
# 2280     0        0         0    0          1         1        0       0
# 2298     0        0         0    0          0         0        0       0
# 2299     0        0         0    0          0         1        0       0
# 2307     0        0         0    0          0         1        0       0
# 2310     0        0         0    0          1         1        0       0
# 2313     1        0         0    0          0         1        0       0
# 2323     1        0         0    0          0         1        0       0
# 2331     0        0         1    0          0         1        0       0
# 2333     1        0         0    0          0         1        0       0
# 2341     0        0         0    0          1         1        0       0
# 2347     1        0         0    0          0         1        0       0
# 2349     1        0         0    0          0         1        0       0
#
#       Happy  Hungry      ...        Sweet  Tar  Tea  Tobacco  Tree  Tropical  \
# 5         0       0      ...            0    0    0        0     0         0
# 6         1       1      ...            1    0    0        0     0         0
# 9         1       0      ...            1    0    0        0     0         0
# 16        0       0      ...            0    0    0        0     0         0
# 17        1       1      ...            1    0    0        0     0         0
# 23        1       0      ...            0    0    0        0     0         0
# 29        1       1      ...            1    0    0        0     0         0
# 33        1       0      ...            1    0    0        0     0         0
# 42        0       0      ...            1    0    0        0     0         0
# 43        1       1      ...            1    0    0        0     0         0
# 49        1       1      ...            1    0    0        0     0         0
# 54        0       0      ...            0    0    0        0     0         0
# 56        1       0      ...            0    0    0        0     0         0
# 72        1       0      ...            1    0    0        0     0         0
# 73        1       0      ...            0    0    0        0     0         0
# 78        1       0      ...            0    0    0        0     0         0
# 94        0       0      ...            0    0    0        0     0         0
# 106       0       0      ...            0    0    0        0     0         0
# 110       1       1      ...            1    0    0        0     0         0
# 112       1       0      ...            1    0    0        0     0         0
# 126       1       0      ...            1    0    0        0     0         0
# 137       1       0      ...            1    0    0        0     0         0
# 142       1       1      ...            1    0    0        0     0         0
# 150       1       1      ...            1    0    0        0     0         0
# 151       1       1      ...            1    0    0        0     0         0
# 177       1       0      ...            1    0    0        0     0         0
# 187       0       0      ...            0    0    0        0     0         0
# 190       1       1      ...            1    0    0        0     0         0
# 191       1       0      ...            0    0    0        0     0         0
# 192       1       0      ...            1    0    0        0     0         0
# ...     ...     ...      ...          ...  ...  ...      ...   ...       ...
# 2174      0       0      ...            0    0    0        0     0         0
# 2179      1       0      ...            0    0    0        0     0         0
# 2180      1       1      ...            1    0    0        0     0         0
# 2201      1       0      ...            0    0    0        0     0         0
# 2202      0       0      ...            0    0    0        0     0         0
# 2220      1       1      ...            1    0    0        0     0         0
# 2229      1       0      ...            0    0    0        0     0         0
# 2231      1       1      ...            1    0    0        0     0         0
# 2249      1       0      ...            0    0    0        0     0         0
# 2256      1       0      ...            0    0    0        0     0         0
# 2262      1       0      ...            1    0    0        0     0         0
# 2264      1       0      ...            1    0    0        0     0         0
# 2269      0       0      ...            0    0    0        0     0         0
# 2270      1       0      ...            1    0    0        0     0         0
# 2273      1       1      ...            1    0    0        0     0         0
# 2274      1       0      ...            1    0    0        0     0         0
# 2276      1       0      ...            1    0    0        0     0         0
# 2278      1       1      ...            1    0    0        0     0         0
# 2280      1       0      ...            1    0    0        0     0         0
# 2298      0       0      ...            0    0    0        0     0         0
# 2299      1       1      ...            1    0    0        0     0         0
# 2307      1       0      ...            1    0    0        0     0         0
# 2310      1       0      ...            0    0    0        0     0         0
# 2313      1       0      ...            1    0    0        0     0         0
# 2323      1       1      ...            1    0    0        0     0         0
# 2331      1       0      ...            1    0    0        0     0         0
# 2333      1       0      ...            0    0    0        0     0         0
# 2341      1       0      ...            1    0    0        0     0         0
# 2347      1       0      ...            1    0    0        0     0         0
# 2349      1       1      ...            1    0    0        0     0         0
#
#       Vanilla  Violet  Woody  is_duplicated
# 5           0       0      0           True
# 6           0       0      0           True
# 9           0       0      0           True
# 16          0       0      0           True
# 17          0       0      0           True
# 23          0       0      1           True
# 29          0       0      1           True
# 33          0       0      0           True
# 42          0       0      0           True
# 43          0       0      0           True
# 49          0       0      1           True
# 54          0       0      0           True
# 56          0       0      0           True
# 72          0       0      1           True
# 73          0       0      1           True
# 78          0       0      0           True
# 94          0       0      0           True
# 106         0       0      0           True
# 110         0       0      0           True
# 112         0       0      0           True
# 126         0       0      0           True
# 137         0       0      0           True
# 142         0       0      1           True
# 150         0       0      0           True
# 151         0       0      0           True
# 177         0       0      0           True
# 187         0       0      0           True
# 190         0       0      0           True
# 191         0       0      0           True
# 192         0       0      0           True
# ...       ...     ...    ...            ...
# 2174        0       0      0           True
# 2179        0       0      0           True
# 2180        0       0      0           True
# 2201        0       0      0           True
# 2202        0       0      0           True
# 2220        0       0      0           True
# 2229        0       0      0           True
# 2231        0       0      1           True
# 2249        0       0      0           True
# 2256        0       0      0           True
# 2262        0       0      0           True
# 2264        0       0      0           True
# 2269        0       0      0           True
# 2270        0       0      0           True
# 2273        0       0      1           True
# 2274        0       0      0           True
# 2276        0       0      0           True
# 2278        0       0      0           True
# 2280        0       0      0           True
# 2298        0       0      0           True
# 2299        0       0      0           True
# 2307        0       0      0           True
# 2310        0       0      1           True
# 2313        0       0      0           True
# 2323        0       0      0           True
# 2331        0       0      0           True
# 2333        0       0      1           True
# 2341        0       0      0           True
# 2347        0       0      0           True
# 2349        0       0      0           True
#
# [382 rows x 66 columns]
